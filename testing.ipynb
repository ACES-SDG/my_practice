# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Users/acesi/OneDrive/Desktop/Excel_files/Sample - Superstore.xlsx')
# Out:
# c:\Users\acesi\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date Customer ID    Customer Name  \
# 0  CA-2018-152156 2018-11-08 2018-11-11    CG-12520      Claire Gute
# 1  CA-2018-152156 2018-11-08 2018-11-11    CG-12520      Claire Gute
# 2  CA-2018-138688 2018-06-12 2018-06-16    DV-13045  Darrin Van Huff
# 3  US-2017-108966 2017-10-11 2017-10-18    SO-20335   Sean O'Donnell
# 4  US-2017-108966 2017-10-11 2017-10-18    SO-20335   Sean O'Donnell
#
#   Country/Region             City       State  Postal Code Region  \
# 0  United States        Henderson    Kentucky        42420  South
# 1  United States        Henderson    Kentucky        42420  South
# 2  United States      Los Angeles  California        90036   West
# 3  United States  Fort Lauderdale     Florida        33311  South
# 4  United States  Fort Lauderdale     Florida        33311  South
#
#         Product ID         Category Sub-Category     Sales  Quantity  \
# 0  FUR-BO-10001798        Furniture    Bookcases  261.9600         2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        10 non-null     object
#  1   Order Date      10 non-null     datetime64[ns]
#  2   Ship Date       10 non-null     datetime64[ns]
#  3   Customer ID     10 non-null     object
#  4   Customer Name   10 non-null     object
#  5   Country/Region  10 non-null     object
#  6   City            10 non-null     object
#  7   State           10 non-null     object
#  8   Postal Code     10 non-null     int64
#  9   Region          10 non-null     object
#  10  Product ID      10 non-null     object
#  11  Category        10 non-null     object
#  12  Sub-Category    10 non-null     object
#  13  Sales           10 non-null     float64
#  14  Quantity        10 non-null     int64
#  15  Discount        10 non-null     float64
#  16  Profit          10 non-null     float64
# ...

# %%
df['Sales'].dtypes
# Out:
# dtype('float64')

# %%
df['Sales'].convert_dtypes()
# Out:
# 0      261.96
# 1      731.94
# 2       14.62
# 3    957.5775
# 4      22.368
# 5       48.86
# 6        7.28
# 7     907.152
# 8      18.504
# 9       114.9
# Name: Sales, dtype: Float64

# %%
df['Sales'].dtype
# Out:
# dtype('float64')

# %%
df.convert_dtypes()
# Out:
#          Order ID Order Date  Ship Date Customer ID    Customer Name  \
# 0  CA-2018-152156 2018-11-08 2018-11-11    CG-12520      Claire Gute
# 1  CA-2018-152156 2018-11-08 2018-11-11    CG-12520      Claire Gute
# 2  CA-2018-138688 2018-06-12 2018-06-16    DV-13045  Darrin Van Huff
# 3  US-2017-108966 2017-10-11 2017-10-18    SO-20335   Sean O'Donnell
# 4  US-2017-108966 2017-10-11 2017-10-18    SO-20335   Sean O'Donnell
# 5  CA-2016-115812 2016-06-09 2016-06-14    BH-11710  Brosina Hoffman
# 6  CA-2016-115812 2016-06-09 2016-06-14    BH-11710  Brosina Hoffman
# 7  CA-2016-115812 2016-06-09 2016-06-14    BH-11710  Brosina Hoffman
# 8  CA-2016-115812 2016-06-09 2016-06-14    BH-11710  Brosina Hoffman
# 9  CA-2016-115812 2016-06-09 2016-06-14    BH-11710  Brosina Hoffman
#
#   Country/Region             City       State  Postal Code Region  \
# 0  United States        Henderson    Kentucky        42420  South
# 1  United States        Henderson    Kentucky        42420  South
# ...

# %%
df.dtypes
# Out:
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Customer ID               object
# Customer Name             object
# Country/Region            object
# City                      object
# State                     object
# Postal Code                int64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        10 non-null     object
#  1   Order Date      10 non-null     datetime64[ns]
#  2   Ship Date       10 non-null     datetime64[ns]
#  3   Customer ID     10 non-null     object
#  4   Customer Name   10 non-null     object
#  5   Country/Region  10 non-null     object
#  6   City            10 non-null     object
#  7   State           10 non-null     object
#  8   Postal Code     10 non-null     int64
#  9   Region          10 non-null     object
#  10  Product ID      10 non-null     object
#  11  Category        10 non-null     object
#  12  Sub-Category    10 non-null     object
#  13  Sales           10 non-null     float64
#  14  Quantity        10 non-null     int64
#  15  Discount        10 non-null     float64
#  16  Profit          10 non-null     float64
# ...

# %%
if df['Category'].dtypes == 'object' :
    print('True')
else:
    print(False)
# Out:
# True

# %%
print(is ( df['Sales'].dtypes  ))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\acesi\OneDrive\Desktop\Aces\my_practice\testing.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/acesi/OneDrive/Desktop/Aces/my_practice/testing.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> print(isinstance( df['Sales'].dtype ))
#
# TypeError: isinstance expected 2 arguments, got 1

# %%
print(df['Sales'].dtypes)
# Out:
# float64
